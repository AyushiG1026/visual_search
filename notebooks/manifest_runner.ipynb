# %% [markdown]
# # Manifest & Thumbnails Runner\nThis notebook is a template for generating `manifest.csv` and thumbnails for the dataset.\n\nSteps to be added:\n1. Mount Google Drive\n2. Verify data structure (`raw/`, `annotations/`)\n3. Run manifest script (to be added later)\n4. Inspect first 10 lines of manifest.csv\n5. Review thumbnails

# %%
# Placeholder: mount Google Drive\nfrom google.colab import drive\ndrive.mount('/content/drive')
